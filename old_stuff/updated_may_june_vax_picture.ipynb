# %% [markdown]
# # How many lives did COVID-19 vaccines save in May/June 2021?

# %%
import makedalytics as ma
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib import rc
from datetime import datetime
from datetime import date
from pandas.tseries.offsets import DateOffset
# math libraries and packages
import math as mth
#from scipy import stats
#fancy visualization and other fancy libraries and packages
import datetime as dt
from IPython.display import Markdown, display
##import plotly.express as px

# %% [markdown]
# ## How many actual cases and deaths were there?

# %%
lancet_age_split= pd.read_csv('D:/MAXCORlabwork/covid/most_current_csvs/corona_age_and_gender_ver_00117.csv')

# %%
lancet_age_split
# Out:
#      first_week_day last_week_day age_group   gender weekly_tests_num  \
# 0         3/15/2020     3/21/2020      0-19      ???             1028
# 1         3/15/2020     3/21/2020      0-19  ?? ????              <15
# 2         3/15/2020     3/21/2020      0-19     ????              838
# 3         3/15/2020     3/21/2020     20-24      ???              666
# 4         3/15/2020     3/21/2020     20-24  ?? ????              <15
# ...             ...           ...       ...      ...              ...
# 3003      6/27/2021      7/3/2021       80+  ?? ????              134
# 3004      6/27/2021      7/3/2021       80+     ????             8920
# 3005      6/27/2021      7/3/2021       NaN      ???             3477
# 3006      6/27/2021      7/3/2021       NaN  ?? ????             6296
# 3007      6/27/2021      7/3/2021       NaN     ????             5071
#
#      weekly_cases weekly_deceased
# 0              32               0
# 1               0               0
# 2              34               0
# 3              99               0
# 4               0               0
# ...           ...             ...
# 3003            0               0
# 3004          <15               0
# 3005          <15               0
# 3006          <15               0
# 3007          <15               0
#
# [3008 rows x 7 columns]

# %%
lancet_age_split.age_group.unique()
# Out:
# array(['0-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49',
#        '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+', nan],
#       dtype=object)

# %%
print("some lines have no age recorded. out of 2008 rows we have ")
print(len(lancet_age_split[lancet_age_split.age_group.isna()]))
print("without age recorded , or")
print((len(lancet_age_split[lancet_age_split.age_group.isna()])/len(lancet_age_split))*100, "percent")
# Out:
# some lines have no age recorded. out of 2008 rows we have
# 204
# without age recorded , or
# 6.781914893617021 percent

# %%
lancet_age_split.tail(4)
# Out:
#      first_week_day last_week_day age_group   gender weekly_tests_num  \
# 3004      6/27/2021      7/3/2021       80+     ????             8920
# 3005      6/27/2021      7/3/2021       NaN      ???             3477
# 3006      6/27/2021      7/3/2021       NaN  ?? ????             6296
# 3007      6/27/2021      7/3/2021       NaN     ????             5071
#
#      weekly_cases weekly_deceased
# 3004          <15               0
# 3005          <15               0
# 3006          <15               0
# 3007          <15               0

# %%
lancet_age_split = lancet_age_split.drop(['last_week_day', 'gender'], axis = 1  )

# %%
lancet_age_split['weekly_cases'] = lancet_age_split['weekly_cases'].str.replace('<15', '7')
lancet_age_split['weekly_tests_num'] = lancet_age_split['weekly_tests_num'].str.replace('<15', '7')
lancet_age_split['weekly_deceased'] = lancet_age_split['weekly_deceased'].str.replace('<15', '7')

# %%
lancet_age_split['weekly_cases'] = pd.to_numeric(lancet_age_split['weekly_cases'])
lancet_age_split['weekly_tests_num'] = pd.to_numeric(lancet_age_split['weekly_tests_num'])
lancet_age_split['weekly_deceased'] = pd.to_numeric(lancet_age_split['weekly_deceased'])

# %%
over_70_people = ['70-74','75-79', '80+']
over_50_people = ['50-54', '55-59', '60-64', '65-69', '70-74','75-79', '80+']
#print(type(lancet_age_split.weekly_deceased[4]))

# %%
lancet_age_split['date'] = pd.to_datetime(lancet_age_split['first_week_day'], format= '%m/%d/%Y')
lancet_age_split
#gb['date_as_date'] = pd.to_datetime(gb['VaccinationDate'], format= '%Y-%m-%d')
# Out:
#      first_week_day age_group  weekly_tests_num  weekly_cases  \
# 0         3/15/2020      0-19              1028            32
# 1         3/15/2020      0-19                 7             0
# 2         3/15/2020      0-19               838            34
# 3         3/15/2020     20-24               666            99
# 4         3/15/2020     20-24                 7             0
# ...             ...       ...               ...           ...
# 3003      6/27/2021       80+               134             0
# 3004      6/27/2021       80+              8920             7
# 3005      6/27/2021       NaN              3477             7
# 3006      6/27/2021       NaN              6296             7
# 3007      6/27/2021       NaN              5071             7
#
#       weekly_deceased       date
# 0                   0 2020-03-15
# 1                   0 2020-03-15
# 2                   0 2020-03-15
# 3                   0 2020-03-15
# 4                   0 2020-03-15
# ...               ...        ...
# 3003                0 2021-06-27
# 3004                0 2021-06-27
# 3005                0 2021-06-27
# 3006                0 2021-06-27
# 3007                0 2021-06-27
#
# [3008 rows x 6 columns]

# %%
seventy_plus_age_split = lancet_age_split[lancet_age_split.age_group.isin(over_70_people)]
fifty_plus_age_split = lancet_age_split[lancet_age_split.age_group.isin(over_50_people)]

# %%
seventy_plus_age_split_sum = seventy_plus_age_split.groupby('date').sum()
fifty_plus_age_split_sum = fifty_plus_age_split.groupby('date').sum()

# %%
seventy_plus_age_split_sum = seventy_plus_age_split_sum.reset_index()
may_and_june_70plus = seventy_plus_age_split_sum[seventy_plus_age_split_sum.date > '2021-04-30']

# %%
may_and_june_70plus['cum_sum_may_june_deaths'] = may_and_june_70plus['weekly_deceased'].cumsum()
# Out:
# D:\bin\anaconda3\envs\jupyter_environment\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
may_and_june_70plus
# Out:
#          date  weekly_tests_num  weekly_cases  weekly_deceased  \
# 59 2021-05-02             11884            35               28
# 60 2021-05-09              8856            42               14
# 61 2021-05-16              8528            42               14
# 62 2021-05-23             12472            35               14
# 63 2021-05-30             10922            28                0
# 64 2021-06-06              9149            21                0
# 65 2021-06-13             11629            21                0
# 66 2021-06-20             17854            51                0
# 67 2021-06-27             31354           110                0
#
#     cum_sum_may_june_deaths
# 59                       28
# 60                       42
# 61                       56
# 62                       70
# 63                       70
# 64                       70
# 65                       70
# 66                       70
# 67                       70

# %%
fifty_plus_age_split_sum = fifty_plus_age_split_sum.reset_index()
fifty_plus_age_split_sum[fifty_plus_age_split_sum.date > '2021-04-30']
# Out:
#          date  weekly_tests_num  weekly_cases  weekly_deceased
# 59 2021-05-02             48564           105               49
# 60 2021-05-09             39477            91               35
# 61 2021-05-16             37046            91               21
# 62 2021-05-23             46231            98               35
# 63 2021-05-30             41485            70               14
# 64 2021-06-06             38245            70                0
# 65 2021-06-13             49863            77                0
# 66 2021-06-20             82376           207                7
# 67 2021-06-27            110505           411                0

# %% [markdown]
# ## How many would have been predicted by vaccine efficacy?

# %%
vaccination = pd.read_csv('D:/MAXCORlabwork/covid/most_current_csvs/vaccinated_per_day_2021_07_03.csv')
vaccination['date_as_date'] = pd.to_datetime(vaccination['VaccinationDate'], format= '%Y-%m-%d')
vaccination.head(5)
# Out:
#   VaccinationDate age_group first_dose second_dose date_as_date
# 0      2020-12-20     20-29        392           0   2020-12-20
# 1      2020-12-20     80-89         93           0   2020-12-20
# 2      2020-12-20      0-19         21           0   2020-12-20
# 3      2020-12-20     60-69       1516           0   2020-12-20
# 4      2020-12-20     50-59       1785           0   2020-12-20

# %%
vaccination['second_dose'] = vaccination['second_dose'].str.replace('<15', '0')
vaccination['first_dose'] = vaccination['first_dose'].str.replace('<15', '0')
vaccination['first_dose'] = pd.to_numeric(vaccination['first_dose'])
vaccination['second_dose'] = pd.to_numeric(vaccination['second_dose'])

# %%
age_grouped_to19_vax = vaccination[vaccination.age_group == '0-19'].copy(deep = True)
age_grouped_to29_vax = vaccination[vaccination.age_group == '20-29'].copy(deep = True)
age_grouped_to39_vax = vaccination[vaccination.age_group == '30-39'].copy(deep = True)
age_grouped_to49_vax = vaccination[vaccination.age_group == '40-49'].copy(deep = True)
age_grouped_to59_vax = vaccination[vaccination.age_group == '50-59'].copy(deep = True)
age_grouped_to69_vax = vaccination[vaccination.age_group == '60-69'].copy(deep = True)
age_grouped_to79_vax = vaccination[vaccination.age_group == '70-79'].copy(deep = True)
age_grouped_to89_vax = vaccination[vaccination.age_group == '80-89'].copy(deep = True)
age_grouped_90plus_vax = vaccination[vaccination.age_group == '90+'].copy(deep = True)

# %%
age_grouped_to19_vax = age_grouped_to19_vax.rename(
    columns = {'first_dose':'first_dose_in_0to19',
                'second_dose': 'second_dose_in_0to19'}
    )
age_grouped_to29_vax = age_grouped_to29_vax.rename(
    columns = {'first_dose':'first_dose_in_20to29',
                'second_dose': 'second_dose_in_20to29'}
    )
age_grouped_to39_vax = age_grouped_to39_vax.rename(
    columns = {'first_dose':'first_dose_in_30to39',
                'second_dose': 'second_dose_in_30to39'}
    )
age_grouped_to49_vax = age_grouped_to49_vax.rename(
    columns = {'first_dose':'first_dose_in_40to49',
                'second_dose': 'second_dose_in_40to49'}
    )
age_grouped_to59_vax = age_grouped_to59_vax.rename(
    columns = {'first_dose':'first_dose_in_50to59',
                'second_dose': 'second_dose_in_50to59'}
    )
age_grouped_to69_vax = age_grouped_to69_vax.rename(
    columns = {'first_dose':'first_dose_in_60to69',
                'second_dose': 'second_dose_in_60to69'}
    )
age_grouped_to79_vax = age_grouped_to79_vax.rename(
    columns = {'first_dose':'first_dose_in_70to79',
                'second_dose': 'second_dose_in_70to79'}
    )
age_grouped_to89_vax = age_grouped_to89_vax.rename(
    columns = {'first_dose':'first_dose_in_80to89',
                'second_dose': 'second_dose_in_80to89'}
    )
age_grouped_90plus_vax = age_grouped_90plus_vax.rename(
    columns = {'first_dose':'first_dose_in_90plus',
                'second_dose': 'second_dose_in_90plus'}
    )

# %%
age_grouped_to19_vax = age_grouped_to19_vax.drop('age_group', axis = 1)
age_grouped_to29_vax = age_grouped_to29_vax.drop('age_group', axis = 1)
age_grouped_to39_vax = age_grouped_to39_vax.drop('age_group', axis = 1)
age_grouped_to49_vax = age_grouped_to49_vax.drop('age_group', axis = 1)
age_grouped_to59_vax = age_grouped_to59_vax.drop('age_group', axis = 1)
age_grouped_to69_vax = age_grouped_to69_vax.drop('age_group', axis = 1)
age_grouped_to79_vax = age_grouped_to79_vax.drop('age_group', axis = 1)
age_grouped_to89_vax = age_grouped_to89_vax.drop('age_group', axis = 1)
age_grouped_90plus_vax= age_grouped_90plus_vax.drop('age_group', axis = 1)
age_grouped_90plus_vax
# Out:
#      VaccinationDate  first_dose_in_90plus  second_dose_in_90plus date_as_date
# 7         2020-12-20                     0                      0   2020-12-20
# 13        2020-12-21                   167                      0   2020-12-21
# 18        2020-12-22                   456                      0   2020-12-22
# 30        2020-12-23                  1027                      0   2020-12-23
# 43        2020-12-24                  1349                      0   2020-12-24
# ...              ...                   ...                    ...          ...
# 1700      2021-06-28                     0                      0   2021-06-28
# 1712      2021-06-29                     0                      0   2021-06-29
# 1724      2021-06-30                     0                      0   2021-06-30
# 1728      2021-07-01                     0                      0   2021-07-01
# 1743      2021-07-02                     0                      0   2021-07-02
#
# [187 rows x 4 columns]

# %%
age_grouped_to19_vax = age_grouped_to19_vax.drop('VaccinationDate', axis = 1)
age_grouped_to29_vax = age_grouped_to29_vax.drop('VaccinationDate', axis = 1)
age_grouped_to39_vax = age_grouped_to39_vax.drop('VaccinationDate', axis = 1)
age_grouped_to49_vax = age_grouped_to49_vax.drop('VaccinationDate', axis = 1)
age_grouped_to59_vax = age_grouped_to59_vax.drop('VaccinationDate', axis = 1)
age_grouped_to69_vax = age_grouped_to69_vax.drop('VaccinationDate', axis = 1)
age_grouped_to79_vax = age_grouped_to79_vax.drop('VaccinationDate', axis = 1)
age_grouped_to89_vax = age_grouped_to89_vax.drop('VaccinationDate', axis = 1)
age_grouped_90plus_vax= age_grouped_90plus_vax.drop('VaccinationDate', axis = 1)

# %%
vax_by_age = age_grouped_to19_vax.merge(age_grouped_to29_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to39_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to49_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to59_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to69_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to79_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_to89_vax, on = 'date_as_date')
vax_by_age = vax_by_age.merge(age_grouped_90plus_vax, on = 'date_as_date')

# %%
vax_by_age_over_70 = vax_by_age[['date_as_date','second_dose_in_70to79','second_dose_in_80to89','second_dose_in_90plus',]]

# %%
vax_by_age_over_70
# Out:
#     date_as_date  second_dose_in_70to79  second_dose_in_80to89  \
# 0     2020-12-20                      0                      0
# 1     2020-12-21                      0                      0
# 2     2020-12-22                      0                      0
# 3     2020-12-23                      0                      0
# 4     2020-12-24                      0                      0
# ..           ...                    ...                    ...
# 181   2021-06-28                     46                     22
# 182   2021-06-29                     50                     22
# 183   2021-06-30                     40                     25
# 184   2021-07-01                     44                     19
# 185   2021-07-02                     16                      0
#
#      second_dose_in_90plus
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 181                      0
# 182                      0
# 183                      0
# 184                      0
# 185                      0
#
# [186 rows x 4 columns]

# %%
vax_by_age_over_70['total_vax_over_70'] = vax_by_age_over_70['second_dose_in_70to79'] +vax_by_age_over_70['second_dose_in_80to89']+vax_by_age_over_70['second_dose_in_90plus']
# Out:
# D:\bin\anaconda3\envs\jupyter_environment\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
pop_70to80 = 477368
pop_80to90 = 219172
pop_90plus = 49298
vax_by_age_over_70['cumulative_vax_over_70'] = vax_by_age_over_70['total_vax_over_70'].cumsum()
vax_by_age_over_70['population_over_70'] = pop_70to80 + pop_80to90 + pop_90plus
vax_by_age_over_70['percent_vaxed'] = vax_by_age_over_70['cumulative_vax_over_70']/vax_by_age_over_70['population_over_70']

# %%
vax_by_age_over_70
# Out:
#     date_as_date  second_dose_in_70to79  second_dose_in_80to89  \
# 0     2020-12-20                      0                      0
# 1     2020-12-21                      0                      0
# 2     2020-12-22                      0                      0
# 3     2020-12-23                      0                      0
# 4     2020-12-24                      0                      0
# ..           ...                    ...                    ...
# 181   2021-06-28                     46                     22
# 182   2021-06-29                     50                     22
# 183   2021-06-30                     40                     25
# 184   2021-07-01                     44                     19
# 185   2021-07-02                     16                      0
#
#      second_dose_in_90plus  total_vax_over_70  cumulative_vax_over_70  \
# 0                        0                  0                       0
# 1                        0                  0                       0
# 2                        0                  0                       0
# 3                        0                  0                       0
# 4                        0                  0                       0
# ..                     ...                ...                     ...
# 181                      0                 68                  705303
# 182                      0                 72                  705375
# 183                      0                 65                  705440
# 184                      0                 63                  705503
# 185                      0                 16                  705519
#
#      population_over_70  percent_vaxed
# 0                745838       0.000000
# 1                745838       0.000000
# 2                745838       0.000000
# 3                745838       0.000000
# 4                745838       0.000000
# ..                  ...            ...
# 181              745838       0.945652
# 182              745838       0.945748
# 183              745838       0.945835
# 184              745838       0.945920
# 185              745838       0.945941
#
# [186 rows x 8 columns]

# %%
vax_by_age_over_70[vax_by_age_over_70.date_as_date > '2021-04-30']
# Out:
#     date_as_date  second_dose_in_70to79  second_dose_in_80to89  \
# 132   2021-05-02                    172                     94
# 133   2021-05-03                    194                    112
# 134   2021-05-04                    170                    129
# 135   2021-05-05                    136                    106
# 136   2021-05-06                     78                     53
# 137   2021-05-07                     41                     38
# 138   2021-05-08                      0                      0
# 139   2021-05-09                    154                     86
# 140   2021-05-10                    157                    102
# 141   2021-05-11                    124                     67
# 142   2021-05-12                     93                     70
# 143   2021-05-13                    128                     72
# 144   2021-05-14                     35                     20
# 145   2021-05-16                     27                     17
# 146   2021-05-18                    214                     95
# 147   2021-05-19                    140                     90
# 148   2021-05-20                    133                     81
# 149   2021-05-21                     24                     20
# 150   2021-05-22                      0                      0
# 151   2021-05-23                    101                     45
# 152   2021-05-24                    110                     63
# 153   2021-05-25                     96                     68
# 154   2021-05-26                     88                     51
# 155   2021-05-27                     89                     63
# 156   2021-05-28                     36                      0
# 157   2021-05-30                     78                     35
# 158   2021-05-31                     60                     18
# 159   2021-06-01                     51                     38
# 160   2021-06-02                     44                     26
# 161   2021-06-03                     35                     30
# 162   2021-06-04                     18                      0
# 163   2021-06-06                     30                      0
# 164   2021-06-07                     27                     22
# 165   2021-06-08                     28                      0
# 166   2021-06-09                     48                     28
# 167   2021-06-10                     36                     18
# 168   2021-06-11                      0                      0
# 169   2021-06-13                     35                      0
# 170   2021-06-14                     25                     18
# 171   2021-06-15                     46                     23
# 172   2021-06-16                     46                     29
# 173   2021-06-17                     37                      0
# 174   2021-06-18                      0                      0
# 175   2021-06-20                     42                     18
# 176   2021-06-21                     52                      0
# 177   2021-06-22                     30                      0
# 178   2021-06-23                     39                     21
# 179   2021-06-24                     44                     16
# 180   2021-06-27                     50                     17
# 181   2021-06-28                     46                     22
# 182   2021-06-29                     50                     22
# 183   2021-06-30                     40                     25
# 184   2021-07-01                     44                     19
# 185   2021-07-02                     16                      0
#
#      second_dose_in_90plus  total_vax_over_70  cumulative_vax_over_70  \
# 132                     31                297                  699703
# 133                     49                355                  700058
# 134                     55                354                  700412
# 135                     36                278                  700690
# 136                      0                131                  700821
# 137                      0                 79                  700900
# 138                      0                  0                  700900
# 139                     46                286                  701186
# 140                     51                310                  701496
# 141                     17                208                  701704
# 142                     29                192                  701896
# 143                      0                200                  702096
# 144                      0                 55                  702151
# 145                      0                 44                  702195
# 146                     40                349                  702544
# 147                     30                260                  702804
# 148                     27                241                  703045
# 149                      0                 44                  703089
# 150                      0                  0                  703089
# 151                      0                146                  703235
# 152                     16                189                  703424
# 153                     24                188                  703612
# 154                      0                139                  703751
# 155                     23                175                  703926
# 156                      0                 36                  703962
# 157                      0                113                  704075
# 158                      0                 78                  704153
# 159                      0                 89                  704242
# 160                      0                 70                  704312
# 161                      0                 65                  704377
# 162                      0                 18                  704395
# 163                      0                 30                  704425
# 164                      0                 49                  704474
# 165                      0                 28                  704502
# 166                      0                 76                  704578
# 167                      0                 54                  704632
# 168                      0                  0                  704632
# 169                      0                 35                  704667
# 170                      0                 43                  704710
# 171                      0                 69                  704779
# 172                     15                 90                  704869
# 173                      0                 37                  704906
# 174                      0                  0                  704906
# 175                      0                 60                  704966
# 176                      0                 52                  705018
# 177                      0                 30                  705048
# 178                      0                 60                  705108
# 179                      0                 60                  705168
# 180                      0                 67                  705235
# 181                      0                 68                  705303
# 182                      0                 72                  705375
# 183                      0                 65                  705440
# 184                      0                 63                  705503
# 185                      0                 16                  705519
#
#      population_over_70  percent_vaxed
# 132              745838       0.938143
# 133              745838       0.938619
# 134              745838       0.939094
# 135              745838       0.939467
# 136              745838       0.939642
# 137              745838       0.939748
# 138              745838       0.939748
# 139              745838       0.940132
# 140              745838       0.940547
# 141              745838       0.940826
# 142              745838       0.941084
# 143              745838       0.941352
# 144              745838       0.941426
# 145              745838       0.941485
# 146              745838       0.941953
# 147              745838       0.942301
# 148              745838       0.942624
# 149              745838       0.942683
# 150              745838       0.942683
# 151              745838       0.942879
# 152              745838       0.943132
# 153              745838       0.943384
# 154              745838       0.943571
# 155              745838       0.943805
# 156              745838       0.943854
# 157              745838       0.944005
# 158              745838       0.944110
# 159              745838       0.944229
# 160              745838       0.944323
# 161              745838       0.944410
# 162              745838       0.944434
# 163              745838       0.944475
# 164              745838       0.944540
# 165              745838       0.944578
# 166              745838       0.944680
# 167              745838       0.944752
# 168              745838       0.944752
# 169              745838       0.944799
# 170              745838       0.944857
# 171              745838       0.944949
# 172              745838       0.945070
# 173              745838       0.945119
# 174              745838       0.945119
# 175              745838       0.945200
# 176              745838       0.945270
# 177              745838       0.945310
# 178              745838       0.945390
# 179              745838       0.945471
# 180              745838       0.945561
# 181              745838       0.945652
# 182              745838       0.945748
# 183              745838       0.945835
# 184              745838       0.945920
# 185              745838       0.945941

# %% [markdown]
# ### So we can conclude that the percentage of over 70s vaccinated held nearly steady at  a range from 93.8 to 94.6% or to approximate  about 94.2%. This means that in May and June we had 5.8% of our population over 70 not vaccinated.

# %%
# our over 70 population numbers 
pop_over_70 = pop_70to80 + pop_80to90 + pop_90plus
unvaxed_over_70 = 0.058 * pop_over_70
vaxed_over_70 = 0.942 *pop_over_70
print('unvaxed over 70 =', unvaxed_over_70, 'persons')
print('vaxed over 70=', vaxed_over_70,'persons')
# Out:
# unvaxed over 70 = 43258.604 persons
# vaxed over 70= 702579.396 persons

# %%
unvaxed_over_70_person_days_may_june = unvaxed_over_70 * 61
vaxed_over_70_person_days_may_june = vaxed_over_70 * 61
print('unvaxed over 70 person days=', unvaxed_over_70_person_days_may_june, 'persons-days')
print('vaxed over 70 person days='  , vaxed_over_70_person_days_may_june,'persons-days')
# Out:
# unvaxed over 70 person days= 2638774.844 persons-days
# vaxed over 70 person days= 42857343.155999996 persons-days

# %%
# calculate expected incident of death based on incidence rate per 100000  person-day 
unvaxed_65plusdeaths_per_100000persondays_expected = 6.6
vaxed_65plusdeaths_per_100000persondays_expected = 0.2
unvaxed_65plusdeaths_per_personday_expected = 6.6/100000
vaxed_65plusdeaths_per_personday_expected = 0.2/100000

# %%
## Expected deaths may -june

# %%
# for vaccinated
expected_deaths_for_vax70plus = vaxed_over_70_person_days_may_june * vaxed_65plusdeaths_per_personday_expected

# %%
# for unvaccinated
expected_deaths_for_unvax70plus =unvaxed_over_70_person_days_may_june * unvaxed_65plusdeaths_per_personday_expected

# %%
total_expected_deaths = expected_deaths_for_vax70plus + expected_deaths_for_unvax70plus
total_expected_deaths
# Out:
# 259.87382601599995

# %% [markdown]
# ## So expected deaths in over 70 for May and June, by individual vaccine efficacy was 260.  But real deaths were 70!  There is some kind of extra effect!!!
# ## But was the effect all about government stringency? Let's see

# %%
import_ox = pd.read_csv('https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/OxCGRT_latest.csv')
# Out:
# D:\bin\anaconda3\envs\jupyter_environment\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
israeli_ox = import_ox[import_ox.CountryName == 'Israel']
israeli_ox['date_as_date']=pd.to_datetime(israeli_ox['Date'], format ='%Y%m%d')
israeli_ox= israeli_ox[['date_as_date', 'StringencyIndex']]
israeli_ox = israeli_ox[israeli_ox.date_as_date < dt.datetime(2021,7, 1)].copy(deep = True)
# Out:
# D:\bin\anaconda3\envs\jupyter_environment\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
israeli_ox.to_csv('D:/MAXCORlabwork/covid/most_current_csvs/maxcor_covid_with_oxford_stringency_data.csv')

# %%
israeli_ox
# Out:
#       date_as_date  StringencyIndex
# 87920   2020-01-01             0.00
# 87921   2020-01-02             0.00
# 87922   2020-01-03             0.00
# 87923   2020-01-04             0.00
# 87924   2020-01-05             0.00
# ...            ...              ...
# 88462   2021-06-26            29.63
# 88463   2021-06-27            29.63
# 88464   2021-06-28            29.63
# 88465   2021-06-29            29.63
# 88466   2021-06-30            29.63
#
# [547 rows x 2 columns]

# %%
# show MOH daily deaths
fig, ax = plt.subplots(figsize=(20, 12))

#Add x-axis and y-axis
ax.plot(israeli_ox.date_as_date,
       israeli_ox.StringencyIndex,
       label='p',
       color='blue')



# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="V",
       title="C")

plt.xticks(rotation=45)
plt.legend(loc='upper left')

#plt.axvline(dt.datetime(2021, 3, 15))
plt.axvline(dt.datetime(2021, 5, 1))
plt.axvline(dt.datetime(2021, 7, 1))

# %% [markdown]
# ## So no, actually stringency was much lower than during the period efficacy was determined. We should have gotten even more deaths! Something else is saving us. Let's look at the towns to see if the less vaccinated areas were also seeing drops in deaths different from what we might expect

# %%
city_split= pd.read_csv(
    'D:/MAXCORlabwork/covid/most_current_csvs/corona_city_table_ver_00110.csv'
)

# %%
city_split.tail(5)
# Out:
#        City_Name  City_Code        Date Cumulative_verified_cases  \
# 135718      תקוע       3563  2021-07-02                       285
# 135719      תקוע       3563  2021-07-03                       285
# 135720      תקוע       3563  2021-07-04                       285
# 135721      תקוע       3563  2021-07-05                       285
# 135722      תקוע       3563  2021-07-06                       285
#
#        Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 135718                 286                0                     10217
# 135719                 286                0                     10220
# 135720                 286                0                     10232
# 135721                 286                0                     10243
# 135722                 287                0                     10274
#
#        Cumulated_number_of_diagnostic_tests colour  final_score
# 135718                                10118   ירוק          2.0
# 135719                                10121   ירוק          2.0
# 135720                                10132   ירוק          2.0
# 135721                                10143   ירוק          2.0
# 135722                                10174   ירוק          2.0

# %%
city_split['percent_arab'] = 'to_be_determined'
city_split['percent_haredi'] = 'to_be_determined'
city_split['city_population'] = 'to_be_determined'
city_split
# Out:
#                  City_Name  City_Code        Date Cumulative_verified_cases  \
# 0       אבו ג'ווייעד (שבט)        967  2020-03-11                         0
# 1       אבו ג'ווייעד (שבט)        967  2020-03-12                         0
# 2       אבו ג'ווייעד (שבט)        967  2020-03-13                         0
# 3       אבו ג'ווייעד (שבט)        967  2020-03-14                         0
# 4       אבו ג'ווייעד (שבט)        967  2020-03-15                         0
# ...                    ...        ...         ...                       ...
# 135718                תקוע       3563  2021-07-02                       285
# 135719                תקוע       3563  2021-07-03                       285
# 135720                תקוע       3563  2021-07-04                       285
# 135721                תקוע       3563  2021-07-05                       285
# 135722                תקוע       3563  2021-07-06                       285
#
#        Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 0                        0                0                         0
# 1                        0                0                         0
# 2                        0                0                         0
# 3                        0                0                         0
# 4                        0                0                         0
# ...                    ...              ...                       ...
# 135718                 286                0                     10217
# 135719                 286                0                     10220
# 135720                 286                0                     10232
# 135721                 286                0                     10243
# 135722                 287                0                     10274
#
#        Cumulated_number_of_diagnostic_tests colour  final_score  \
# 0                                         0    NaN          NaN
# 1                                         0    NaN          NaN
# 2                                         0    NaN          NaN
# 3                                         0    NaN          NaN
# 4                                         0    NaN          NaN
# ...                                     ...    ...          ...
# 135718                                10118   ירוק          2.0
# 135719                                10121   ירוק          2.0
# 135720                                10132   ירוק          2.0
# 135721                                10143   ירוק          2.0
# 135722                                10174   ירוק          2.0
#
#             percent_arab    percent_haredi   city_population
# 0       to_be_determined  to_be_determined  to_be_determined
# 1       to_be_determined  to_be_determined  to_be_determined
# 2       to_be_determined  to_be_determined  to_be_determined
# 3       to_be_determined  to_be_determined  to_be_determined
# 4       to_be_determined  to_be_determined  to_be_determined
# ...                  ...               ...               ...
# 135718  to_be_determined  to_be_determined  to_be_determined
# 135719  to_be_determined  to_be_determined  to_be_determined
# 135720  to_be_determined  to_be_determined  to_be_determined
# 135721  to_be_determined  to_be_determined  to_be_determined
# 135722  to_be_determined  to_be_determined  to_be_determined
#
# [135723 rows x 13 columns]

# %%
city_split.City_Name.unique()
# Out:
# array(["אבו ג'ווייעד (שבט)", 'אבו גוש', 'אבו סנאן', 'אבו קורינאת (שבט)',
#        'אבו רובייעה (שבט)', 'אבו רוקייק (שבט)', 'אבו תלול', 'אבטין',
#        'אבן יהודה', 'אבני חפץ', 'אום אל-פחם', 'אום בטין', 'אופקים',
#        'אור יהודה', 'אור עקיבא', 'אורנית', 'אזור', 'אחוזת ברק',
#        'אטרש (שבט)', 'אילת', 'אכסאל', 'אל סייד', 'אלון שבות', 'אליכין',
#        'אלעד', 'אלעזר', 'אלפי מנשה', 'אלקנה', 'אעבלין', 'אעצם (שבט)',
#        'אפרת', 'אריאל', 'אשדוד', 'אשקלון', 'באקה אל-גרביה', 'באר יעקב',
#        'באר שבע', "בועיינה-נוג'ידאת", 'בוקעאתא', 'ביר אל-מכסור',
#        "ביר הדאג'", 'בית אל', 'בית אריה', "בית ג'ן", 'בית דגן',
#        'בית חשמונאי', 'בית יצחק-שער חפר', 'בית שאן', 'בית שמש',
#        'ביתר עילית', 'בני ברק', 'בני עי"ש', 'בנימינה-גבעת עדה', 'בסמ"ה',
#        'בסמת טבעון', 'בענה', 'ברכה', 'ברקת', 'בת חפר', 'בת ים',
#        'גבע בנימין', 'גבעת אבני', 'גבעת ברנר', 'גבעת זאב', 'גבעת שמואל',
#        'גבעתיים', "ג'דיידה-מכר", 'גדרה', "ג'ולס", "ג'לג'וליה", 'גן יבנה',
#        'גן נר', 'גני מודיעין', 'גני תקווה', "ג'סר א-זרקא",
#        "ג'ש (גוש חלב)", "ג'ת", 'דאלית אל-כרמל', 'דבוריה', 'דייר אל-אסד',
#        'דייר חנא', 'דימונה', 'הוד השרון', 'הוואשלה (שבט)', 'הושעיה',
#        'הר אדר', 'הרצליה', 'זכרון יעקב', 'זמר', 'זרזיר', 'חדרה', 'חולון',
#        'חורה', 'חורפיש', 'חיפה', 'חספין', 'חצור הגלילית', 'חריש',
#        'חשמונאים', 'טבריה', 'טובא-זנגריה', 'טורעאן', 'טייבה', 'טירה',
#        'טירת כרמל', 'טלמון', 'טמרה', "יאנוח-ג'ת", 'יבנאל', 'יבנה',
#        'יד בנימין', 'יהוד', 'יפיע', 'יקיר', 'יקנעם עילית', 'ירוחם',
#        'ירושלים', 'ירכא', 'כאבול', "כאוכב אבו אל-היג'א", 'כוכב השחר',
#        'כוכב יאיר', 'כוכב יעקב', 'כסיפה', 'כסרא-סמיע',
#        "כעביה-טבאש-חג'אג'רה", 'כפר אדומים', 'כפר ברא', 'כפר האורנים',
#        'כפר ורדים', 'כפר חב"ד', 'כפר יאסיף', 'כפר יונה', 'כפר כמא',
#        'כפר כנא', 'כפר מנדא', 'כפר מצר', 'כפר סבא', 'כפר קאסם', 'כפר קרע',
#        'כפר תבור', 'כרמיאל', 'לא ידוע', 'להבים', 'לוד', 'לפיד', 'לקיה',
#        'מבוא חורון', 'מבשרת ציון', 'מגאר', "מג'ד אל-כרום", 'מגדל העמק',
#        "מג'דל שמס", 'מודיעין עילית', 'מודיעין-מכבים-רעות', 'מוקייבלה',
#        'מזכרת בתיה', 'מזרעה', 'מייסר', 'מיתר', 'מסעדה',
#        'מסעודין אל-עזאזמה', 'מעגלים', 'מעגן מיכאל', 'מעיליא',
#        'מעלה אדומים', 'מעלה עירון', 'מעלות-תרשיחא', 'מצפה יריחו',
#        'מצפה רמון', 'מרכז שפירא', 'משהד', 'מתן', 'נאעורה', 'נהריה',
#        'נווה דניאל', 'נוף איילון', 'נוף הגליל', 'נופית', 'נוקדים', 'נחף',
#        'ניצן', 'נס ציונה', 'נעלה', 'נצרת', 'נשר', 'נתיבות', 'נתניה',
#        "סאג'ור", 'סביון', 'סולם', "סח'נין", 'סייד (שבט)', 'סלמה', "ע'ג'ר",
#        'עוזייר', 'עומר', 'עיילבון', 'עילוט', 'עין מאהל', 'עין נקובא',
#        'עין קנייא', 'עכו', 'עלי', 'עלי זהב', 'עמנואל', 'עספיא', 'עפולה',
#        'עפרה', 'עץ אפרים', 'עראבה', 'ערד', 'ערערה', 'ערערה-בנגב', 'עתלית',
#        'פדואל', 'פוריידיס', 'פסגות', 'פסוטה', 'פקיעין (בוקייעה)',
#        'פרדס חנה-כרכור', 'פרדסיה', 'פתח תקווה', 'צופים', 'צור הדסה',
#        'צור יצחק', 'צור משה', 'צפת', 'קדומים', 'קדימה-צורן',
#        'קודייראת א-צאנע(שבט)', 'קיסריה', 'קלנסווה', 'קציר', 'קצר א-סר',
#        'קצרין', 'קרית אונו', 'קרית ארבע', 'קרית אתא', 'קרית ביאליק',
#        'קרית גת', 'קרית טבעון', 'קרית ים', 'קרית יערים', 'קרית מוצקין',
#        'קרית מלאכי', 'קרית עקרון', 'קרית שמונה', 'קרני שומרון', 'ראמה',
#        'ראש העין', 'ראש פינה', 'ראשון לציון', 'רבבה', 'רהט', 'רומת הייב',
#        'רחובות', 'ריינה', 'רכסים', 'רמלה', 'רמת גן', 'רמת השרון',
#        'רמת ישי', 'רעננה', 'שבלי - אום אל-גנם', 'שגב-שלום', 'שדרות',
#        'שוהם', "שייח' דנון", 'שילה', 'שלומי', 'שמשית', 'שעב',
#        'שערי תקווה', 'שפרעם', 'שתולים', 'תל אביב - יפו', 'תל מונד',
#        'תל שבע', 'תפרח', 'תקוע'], dtype=object)

# %%
city_split.percent_arab[city_split.City_Name == 'באקה אל-גרביה'] = 100
# Out:
# C:\Users\makeda\AppData\Local\Temp/ipykernel_3036/2667299080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_split.percent_arab[city_split.City_Name == 'באקה אל-גרביה'] = 100

# %%
baka = city_split[city_split.City_Name == 'באקה אל-גרביה']

# %%
baka[baka.Date > '2021-04-30']
# Out:
#            City_Name  City_Code        Date Cumulative_verified_cases  \
# 16838  באקה אל-גרביה       6000  2021-05-01                      2769
# 16839  באקה אל-גרביה       6000  2021-05-02                      2769
# 16840  באקה אל-גרביה       6000  2021-05-03                      2769
# 16841  באקה אל-גרביה       6000  2021-05-04                      2769
# 16842  באקה אל-גרביה       6000  2021-05-05                      2769
# ...              ...        ...         ...                       ...
# 16900  באקה אל-גרביה       6000  2021-07-02                      2772
# 16901  באקה אל-גרביה       6000  2021-07-03                      2772
# 16902  באקה אל-גרביה       6000  2021-07-04                      2772
# 16903  באקה אל-גרביה       6000  2021-07-05                      2772
# 16904  באקה אל-גרביה       6000  2021-07-06                      2773
#
#       Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 16838                2741               25                     34261
# 16839                2741               25                     34285
# 16840                2742               25                     34315
# 16841                2742               25                     34358
# 16842                2742               25                     34380
# ...                   ...              ...                       ...
# 16900                2747               25                     37334
# 16901                2747               25                     37412
# 16902                2748               25                     37489
# 16903                2748               25                     37636
# 16904                2749               25                     37791
#
#       Cumulated_number_of_diagnostic_tests colour  final_score percent_arab  \
# 16838                                31731   ירוק          1.6          100
# 16839                                31755   ירוק          1.7          100
# 16840                                31781   ירוק          1.9          100
# 16841                                31819   ירוק          2.0          100
# 16842                                31837   ירוק          2.0          100
# ...                                    ...    ...          ...          ...
# 16900                                34436   ירוק          0.9          100
# 16901                                34500   ירוק          1.1          100
# 16902                                34570   ירוק          1.2          100
# 16903                                34695   ירוק          1.4          100
# 16904                                34835   ירוק          1.4          100
#
#          percent_haredi   city_population
# 16838  to_be_determined  to_be_determined
# 16839  to_be_determined  to_be_determined
# 16840  to_be_determined  to_be_determined
# 16841  to_be_determined  to_be_determined
# 16842  to_be_determined  to_be_determined
# ...                 ...               ...
# 16900  to_be_determined  to_be_determined
# 16901  to_be_determined  to_be_determined
# 16902  to_be_determined  to_be_determined
# 16903  to_be_determined  to_be_determined
# 16904  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %% [markdown]
# ## So using Baka al Gerbiya as an example, we accumulate zero deaths there, in spite of a presumably lower vaccination rate among it's 30,000 residents than the national average.
# ## Let's look at some other areas - we will pick ones with large populations we expect to have lower vaccination rates- and see

# %% [markdown]
# We would want to look at the following large majority arab locales: ( totalpopulation)
# arab locales: ( total population)
#     Kafr Qasim : (23,823 )
#     Qalansawe: (23,143)
#     Tayibe: (43,957)
#     Tira: (26,552)
#     Arara: (25,245)
#     Baqa al-Gharbiyye: (29,950)
#     Umm al-Fahm: (56,109)

# %%
kfar_kassem = city_split[city_split.City_Name == 'כפר קאסם']
kfar_kassem[kfar_kassem.Date > '2021-04-30']
# Out:
#       City_Name  City_Code        Date Cumulative_verified_cases  \
# 67070  כפר קאסם        634  2021-05-01                      3368
# 67071  כפר קאסם        634  2021-05-02                      3368
# 67072  כפר קאסם        634  2021-05-03                      3368
# 67073  כפר קאסם        634  2021-05-04                      3368
# 67074  כפר קאסם        634  2021-05-05                      3368
# ...         ...        ...         ...                       ...
# 67132  כפר קאסם        634  2021-07-02                      3372
# 67133  כפר קאסם        634  2021-07-03                      3372
# 67134  כפר קאסם        634  2021-07-04                      3372
# 67135  כפר קאסם        634  2021-07-05                      3372
# 67136  כפר קאסם        634  2021-07-06                      3372
#
#       Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 67070                3352              <15                     35684
# 67071                3352              <15                     35722
# 67072                3353              <15                     35742
# 67073                3353              <15                     35794
# 67074                3353              <15                     35821
# ...                   ...              ...                       ...
# 67132                3358              <15                     40329
# 67133                3358              <15                     40409
# 67134                3358              <15                     40526
# 67135                3358              <15                     40741
# 67136                3358              <15                     41080
#
#       Cumulated_number_of_diagnostic_tests colour  final_score  \
# 67070                                32924   ירוק          1.8
# 67071                                32956   ירוק          1.9
# 67072                                32973   ירוק          2.0
# 67073                                33008   ירוק          2.0
# 67074                                33029   ירוק          2.0
# ...                                    ...    ...          ...
# 67132                                36702   ירוק          1.6
# 67133                                36763   ירוק          1.5
# 67134                                36859   ירוק          1.4
# 67135                                37033   ירוק          1.3
# 67136                                37317   ירוק          1.1
#
#            percent_arab    percent_haredi   city_population
# 67070  to_be_determined  to_be_determined  to_be_determined
# 67071  to_be_determined  to_be_determined  to_be_determined
# 67072  to_be_determined  to_be_determined  to_be_determined
# 67073  to_be_determined  to_be_determined  to_be_determined
# 67074  to_be_determined  to_be_determined  to_be_determined
# ...                 ...               ...               ...
# 67132  to_be_determined  to_be_determined  to_be_determined
# 67133  to_be_determined  to_be_determined  to_be_determined
# 67134  to_be_determined  to_be_determined  to_be_determined
# 67135  to_be_determined  to_be_determined  to_be_determined
# 67136  to_be_determined  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %% [markdown]
# So we see in kfar kassem (notable for being mostly muslim and low SES) deaths stayed recorded at under 15 , unfortunately we did not have an exact number. But maybe we don't get an accurate recording in these areas? Is it possible for people to die at home, COVID-19 unrecorded? Must ask Ronen...in the meantime, let's see קלנסווה

# %%
qualansawe = city_split[city_split.City_Name =='קלנסווה']
qualansawe[qualansawe.Date > '2021-04-30']
# Out:
#        City_Name  City_Code        Date Cumulative_verified_cases  \
# 112472   קלנסווה        638  2021-05-01                      2505
# 112473   קלנסווה        638  2021-05-02                      2505
# 112474   קלנסווה        638  2021-05-03                      2505
# 112475   קלנסווה        638  2021-05-04                      2505
# 112476   קלנסווה        638  2021-05-05                      2505
# ...          ...        ...         ...                       ...
# 112534   קלנסווה        638  2021-07-02                      2506
# 112535   קלנסווה        638  2021-07-03                      2506
# 112536   קלנסווה        638  2021-07-04                      2506
# 112537   קלנסווה        638  2021-07-05                      2506
# 112538   קלנסווה        638  2021-07-06                      2506
#
#        Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 112472                2481               16                     32267
# 112473                2481               16                     32298
# 112474                2483               16                     32402
# 112475                2483               16                     32443
# 112476                2483               16                     32542
# ...                    ...              ...                       ...
# 112534                2492               16                     35303
# 112535                2492               16                     35367
# 112536                2493               16                     35424
# 112537                2493               16                     35537
# 112538                2493               16                     35666
#
#        Cumulated_number_of_diagnostic_tests colour  final_score  \
# 112472                                29831   ירוק          1.3
# 112473                                29858   ירוק          1.2
# 112474                                29949   ירוק          1.3
# 112475                                29989   ירוק          1.4
# 112476                                30075   ירוק          1.6
# ...                                     ...    ...          ...
# 112534                                32425   ירוק          1.5
# 112535                                32479   ירוק          1.4
# 112536                                32526   ירוק          1.3
# 112537                                32608   ירוק          1.2
# 112538                                32716   ירוק          1.3
#
#             percent_arab    percent_haredi   city_population
# 112472  to_be_determined  to_be_determined  to_be_determined
# 112473  to_be_determined  to_be_determined  to_be_determined
# 112474  to_be_determined  to_be_determined  to_be_determined
# 112475  to_be_determined  to_be_determined  to_be_determined
# 112476  to_be_determined  to_be_determined  to_be_determined
# ...                  ...               ...               ...
# 112534  to_be_determined  to_be_determined  to_be_determined
# 112535  to_be_determined  to_be_determined  to_be_determined
# 112536  to_be_determined  to_be_determined  to_be_determined
# 112537  to_be_determined  to_be_determined  to_be_determined
# 112538  to_be_determined  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %% [markdown]
# OK, no budge in deaths there either. Now let's check the Arab muslim majority city with the largest numbers

# %%
tayibe = city_split[city_split.City_Name == 'טייבה']
tayibe[tayibe.Date > '2021-04-30']
# Out:
#       City_Name  City_Code        Date Cumulative_verified_cases  \
# 49682     טייבה       2730  2021-05-01                      4609
# 49683     טייבה       2730  2021-05-02                      4609
# 49684     טייבה       2730  2021-05-03                      4611
# 49685     טייבה       2730  2021-05-04                      4611
# 49686     טייבה       2730  2021-05-05                      4611
# ...         ...        ...         ...                       ...
# 49744     טייבה       2730  2021-07-02                      4623
# 49745     טייבה       2730  2021-07-03                      4623
# 49746     טייבה       2730  2021-07-04                      4623
# 49747     טייבה       2730  2021-07-05                      4624
# 49748     טייבה       2730  2021-07-06                      4626
#
#       Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 49682                4541               45                     59382
# 49683                4546               45                     59441
# 49684                4547               45                     59977
# 49685                4551               45                     60082
# 49686                4554               45                     60658
# ...                   ...              ...                       ...
# 49744                4571               45                     67114
# 49745                4571               45                     67271
# 49746                4571               45                     67432
# 49747                4571               45                     67735
# 49748                4572               45                     68107
#
#       Cumulated_number_of_diagnostic_tests colour  final_score  \
# 49682                                55677   ירוק          2.7
# 49683                                55732   ירוק          2.8
# 49684                                56206   ירוק          2.7
# 49685                                56294   ירוק          2.5
# 49686                                56793   ירוק          2.1
# ...                                    ...    ...          ...
# 49744                                62306   ירוק          2.0
# 49745                                62440   ירוק          2.1
# 49746                                62578   ירוק          2.2
# 49747                                62820   ירוק          2.3
# 49748                                63124   ירוק          2.4
#
#            percent_arab    percent_haredi   city_population
# 49682  to_be_determined  to_be_determined  to_be_determined
# 49683  to_be_determined  to_be_determined  to_be_determined
# 49684  to_be_determined  to_be_determined  to_be_determined
# 49685  to_be_determined  to_be_determined  to_be_determined
# 49686  to_be_determined  to_be_determined  to_be_determined
# ...                 ...               ...               ...
# 49744  to_be_determined  to_be_determined  to_be_determined
# 49745  to_be_determined  to_be_determined  to_be_determined
# 49746  to_be_determined  to_be_determined  to_be_determined
# 49747  to_be_determined  to_be_determined  to_be_determined
# 49748  to_be_determined  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %%
# So we seee zero cumulated deaths here as well even in Tayibe...let's check umm al fahn

# %%
um_al_fahn = city_split[city_split.City_Name == 'אום אל-פחם']
um_al_fahn[um_al_fahn.Date > '2021-04-30']
# Out:
#        City_Name  City_Code        Date Cumulative_verified_cases  \
# 5246  אום אל-פחם       2710  2021-05-01                      6168
# 5247  אום אל-פחם       2710  2021-05-02                      6169
# 5248  אום אל-פחם       2710  2021-05-03                      6169
# 5249  אום אל-פחם       2710  2021-05-04                      6170
# 5250  אום אל-פחם       2710  2021-05-05                      6170
# ...          ...        ...         ...                       ...
# 5308  אום אל-פחם       2710  2021-07-02                      6186
# 5309  אום אל-פחם       2710  2021-07-03                      6186
# 5310  אום אל-פחם       2710  2021-07-04                      6186
# 5311  אום אל-פחם       2710  2021-07-05                      6186
# 5312  אום אל-פחם       2710  2021-07-06                      6186
#
#      Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 5246                6097               59                     58864
# 5247                6098               59                     58904
# 5248                6099               59                     58971
# 5249                6100               59                     59019
# 5250                6100               59                     59059
# ...                  ...              ...                       ...
# 5308                6126               59                     63118
# 5309                6126               59                     63314
# 5310                6129               59                     63415
# 5311                6129               59                     63551
# 5312                6129               59                     63816
#
#      Cumulated_number_of_diagnostic_tests colour  final_score  \
# 5246                                55338   ירוק          1.9
# 5247                                55376   ירוק          2.1
# 5248                                55436   ירוק          2.2
# 5249                                55476   ירוק          2.1
# 5250                                55516   ירוק          2.0
# ...                                   ...    ...          ...
# 5308                                59083   ירוק          1.6
# 5309                                59248   ירוק          1.7
# 5310                                59335   ירוק          1.7
# 5311                                59453   ירוק          1.8
# 5312                                59678   ירוק          1.9
#
#           percent_arab    percent_haredi   city_population
# 5246  to_be_determined  to_be_determined  to_be_determined
# 5247  to_be_determined  to_be_determined  to_be_determined
# 5248  to_be_determined  to_be_determined  to_be_determined
# 5249  to_be_determined  to_be_determined  to_be_determined
# 5250  to_be_determined  to_be_determined  to_be_determined
# ...                ...               ...               ...
# 5308  to_be_determined  to_be_determined  to_be_determined
# 5309  to_be_determined  to_be_determined  to_be_determined
# 5310  to_be_determined  to_be_determined  to_be_determined
# 5311  to_be_determined  to_be_determined  to_be_determined
# 5312  to_be_determined  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %% [markdown]
# ## I can't find Araraa ask Ronen for help with spelling maybe?

# %% [markdown]
# #arara = city_split[city_split.City_Name == ערערע']
# #arara[arara.Date > '2021-04-30']

# %% [markdown]
# # Same story in Kfar Kassem, Um al Fahn, Tayibe, Baka, Qualansawe!!! So it seems the surrounding population vaccinating seems to be protecting them from at least deaths. Now what happened in Bnei Barak?

# %%
bnei_barak = city_split[city_split.City_Name == 'בני ברק']
bnei_barak[bnei_barak.Date > '2021-04-30']
# Out:
#       City_Name  City_Code        Date Cumulative_verified_cases  \
# 24566   בני ברק       6100  2021-05-01                     48239
# 24567   בני ברק       6100  2021-05-02                     48239
# 24568   בני ברק       6100  2021-05-03                     48239
# 24569   בני ברק       6100  2021-05-04                     48239
# 24570   בני ברק       6100  2021-05-05                     48239
# ...         ...        ...         ...                       ...
# 24628   בני ברק       6100  2021-07-02                     48248
# 24629   בני ברק       6100  2021-07-03                     48248
# 24630   בני ברק       6100  2021-07-04                     48248
# 24631   בני ברק       6100  2021-07-05                     48248
# 24632   בני ברק       6100  2021-07-06                     48248
#
#       Cumulated_recovered Cumulated_deaths Cumulated_number_of_tests  \
# 24566               47991              229                    375859
# 24567               47993              229                    376193
# 24568               47993              229                    376426
# 24569               47993              229                    376755
# 24570               47993              230                    376999
# ...                   ...              ...                       ...
# 24628               48015              230                    392659
# 24629               48016              230                    392892
# 24630               48016              230                    393155
# 24631               48017              230                    393601
# 24632               48017              230                    394195
#
#       Cumulated_number_of_diagnostic_tests colour  final_score  \
# 24566                               346125   ירוק          0.5
# 24567                               346410   ירוק          0.5
# 24568                               346611   ירוק          0.5
# 24569                               346909   ירוק          0.5
# 24570                               347121   ירוק          0.3
# ...                                    ...    ...          ...
# 24628                               360021   ירוק          0.1
# 24629                               360185   ירוק          0.1
# 24630                               360400   ירוק          0.2
# 24631                               360758   ירוק          0.2
# 24632                               361245   ירוק          0.2
#
#            percent_arab    percent_haredi   city_population
# 24566  to_be_determined  to_be_determined  to_be_determined
# 24567  to_be_determined  to_be_determined  to_be_determined
# 24568  to_be_determined  to_be_determined  to_be_determined
# 24569  to_be_determined  to_be_determined  to_be_determined
# 24570  to_be_determined  to_be_determined  to_be_determined
# ...                 ...               ...               ...
# 24628  to_be_determined  to_be_determined  to_be_determined
# 24629  to_be_determined  to_be_determined  to_be_determined
# 24630  to_be_determined  to_be_determined  to_be_determined
# 24631  to_be_determined  to_be_determined  to_be_determined
# 24632  to_be_determined  to_be_determined  to_be_determined
#
# [67 rows x 13 columns]

# %% [markdown]
# ## In Bnei Barak they added on single death in May and June! Looks like the less vaccinated areas are benefiting from us!

# %% [markdown]
# ## We could sum these areas populations, get person years, then get some kind of expected deaths...
# But this is too much work for very little reward when the number is about ZERO barring the onme Bnei barak...

# %% [markdown]
# # Let's think about the most important questions:
# 1. Is the same true for the general population. Did we get lower deaths than expected in young people as well?
# 2. How much is reduced transmission, versus reduced deadlyness once you catch it?

# %% [markdown]
# ## Proposed calculations to adress these and other questions:
#
# 1. Try, given whatever data possible, to calculate the expected and real cases for whole population
#
# 2. Look at percentages of people who catch the virus in an age group who die over time (some more MOH data may be neccesary).
